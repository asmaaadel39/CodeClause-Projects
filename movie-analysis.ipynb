# %% [markdown]
# <a href="https://www.kaggle.com/code/asmaaadel39/movie-analysis?scriptVersionId=112161339" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/bollywood-movie-dataset/BollywoodActorRanking.csv
# /kaggle/input/bollywood-movie-dataset/BollywoodDirectorRanking.csv
# /kaggle/input/bollywood-movie-dataset/BollywoodMovieDetail.csv

# %% [markdown]
# # Task 1, Movie Analysis Project

# %%
import pandas as pd 
Actor=pd.read_csv('/kaggle/input/bollywood-movie-dataset/BollywoodActorRanking.csv')
Director=pd.read_csv('/kaggle/input/bollywood-movie-dataset/BollywoodDirectorRanking.csv')
Movie_=pd.read_csv('/kaggle/input/bollywood-movie-dataset/BollywoodMovieDetail.csv')

# %%
Actor.head()
# Out:
#    actorId         actorName  movieCount  ratingSum  normalizedMovieRank  \
# 0      373        Aamir Khan          11       1170              9.44862
# 1      374    Shah Rukh Khan          23       2000              7.55009
# 2      375       Salman Khan          36       2340              5.40217
# 3      376      Katrina Kaif          17       1640              8.48082
# 4      377  Deepika Padukone          16       1080              5.64674
#
#    googleHits  normalizedGoogleRank  normalizedRating
# 0     2460000               7.34283          10.00000
# 1     2670000               7.88458           9.22674
# 2     3490000              10.00000           9.20821
# 3     2120000               6.46570           8.94852
# 4     3000000               8.73591           8.62716

# %%
Director.head()
# Out:
#    directorId     directorName  movieCount  ratingSum  normalizedMovieRank  \
# 0           1  Rajkumar Hirani           3        440             10.00000
# 1           2       Farah Khan           4        440              7.39474
# 2           3      Karan Johar           5        430              5.68947
# 3           4       Sajid Khan           4        350              5.79605
# 4           5     Rohit Shetty          10        950              6.32895
#
#    googleHits  normalizedGoogleRank  normalizedRating
# 0      146000               2.07796          10.00000
# 1     1060000               8.88317           8.78473
# 2     1050000               8.80872           7.10460
# 3      905000               7.72912           6.99780
# 4      437000               4.24461           6.83761

# %%
Movie_.head()
# Out:
#       imdbId                              title  releaseYear  releaseDate  \
# 0  tt0118578                             Albela         2001  20 Apr 2001
# 1  tt0169102  Lagaan: Once Upon a Time in India         2001  08 May 2002
# 2  tt0187279           Meri Biwi Ka Jawab Nahin         2004  02 Jul 2004
# 3  tt0222024             Hum Tumhare Hain Sanam         2002  24 May 2002
# 4  tt0227194                         One 2 Ka 4         2001  30 Mar 2001
#
#                          genre  \
# 0                      Romance
# 1  Adventure | Drama | Musical
# 2              Action | Comedy
# 3              Drama | Romance
# 4      Action | Comedy | Drama
#
#                                              writers  \
# 0  Honey Irani (screenplay) | Honey Irani (story)...
# 1  Ashutosh Gowariker (story) | Ashutosh Gowarike...
# 2                                                NaN
# 3  K.S. Adiyaman | Arun Kumar (assistant dialogue...
# 4  Sanjay Chhel | Raaj Kumar Dahima (screenplay) ...
#
# ...

# %% [markdown]
# # **Actor dataset**

# %%
Actor.shape
# we got 301 rows and 8 columns
# Out:
# (301, 8)

# %%
Actor.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301 entries, 0 to 300
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   actorId               301 non-null    int64
#  1   actorName             301 non-null    object
#  2   movieCount            301 non-null    int64
#  3   ratingSum             301 non-null    int64
#  4   normalizedMovieRank   299 non-null    float64
#  5   googleHits            301 non-null    int64
#  6   normalizedGoogleRank  189 non-null    float64
#  7   normalizedRating      301 non-null    float64
# dtypes: float64(3), int64(4), object(1)
# memory usage: 18.9+ KB

# %%
Actor.isna().sum()
#After checking how many missing values we have
#We got 112 for normalizedGoogleRank column and 2 for normilzedMovieRank column
# Out:
# actorId                   0
# actorName                 0
# movieCount                0
# ratingSum                 0
# normalizedMovieRank       2
# googleHits                0
# normalizedGoogleRank    112
# normalizedRating          0
# dtype: int64

# %%
 Actor.dropna(inplace=True)
# The default value of this attribute inplace is False and it returns the copy of the object.

# %%
Actor.isna().sum()
# Out:
# actorId                 0
# actorName               0
# movieCount              0
# ratingSum               0
# normalizedMovieRank     0
# googleHits              0
# normalizedGoogleRank    0
# normalizedRating        0
# dtype: int64

# %%
Actor.shape
# Out:
# (189, 8)

# %%
Actor.describe()
# Out:
#           actorId  movieCount    ratingSum  normalizedMovieRank    googleHits  \
# count  189.000000  189.000000   189.000000           189.000000  1.890000e+02
# mean   482.566138   13.703704   578.201058             2.987354  5.959299e+05
# std     69.269149    9.086876   496.971618             1.653698  7.564603e+05
# min    373.000000    4.000000   100.000000             1.000000  1.330000e+03
# 25%    422.000000    8.000000   250.000000             1.827760  9.540000e+04
# 50%    479.000000   11.000000   380.000000             2.565220  2.490000e+05
# 75%    540.000000   17.000000   740.000000             3.746660  7.640000e+05
# max    608.000000   54.000000  2950.000000            10.000000  3.490000e+06
#
#        normalizedGoogleRank  normalizedRating
# count            189.000000        189.000000
# mean               2.533937          3.576815
# std                1.951501          1.797680
# min                1.000000          1.569930
# ...

# %%
Actor.max()
# The Max function get the max value in each column
# Out:
# actorId                        608
# actorName               Zayed Khan
# movieCount                      54
# ratingSum                     2950
# normalizedMovieRank           10.0
# googleHits                 3490000
# normalizedGoogleRank          10.0
# normalizedRating              10.0
# dtype: object

# %%
Actor.min()
# The Min function get the Min value in each column
# Out:
# actorId                        373
# actorName               Aamir Khan
# movieCount                       4
# ratingSum                      100
# normalizedMovieRank            1.0
# googleHits                    1330
# normalizedGoogleRank           1.0
# normalizedRating           1.56993
# dtype: object

# %%
afternormalized=Actor.nlargest(10,"normalizedRating")
afternormalized
#The nlargest() method returns a specified number of rows, 
#starting at the top after sorting the DataFrame by the highest value for a specified column.
# Out:
#    actorId         actorName  movieCount  ratingSum  normalizedMovieRank  \
# 0      373        Aamir Khan          11       1170              9.44862
# 1      374    Shah Rukh Khan          23       2000              7.55009
# 2      375       Salman Khan          36       2340              5.40217
# 3      376      Katrina Kaif          17       1640              8.48082
# 4      377  Deepika Padukone          16       1080              5.64674
# 5      378    Hrithik Roshan          16       1120              5.89130
# 6      379   Priyanka Chopra          36       1990              4.45109
# 7      380    Kareena Kapoor          37       2200              4.86016
# 8      381     Ranbir Kapoor          11        890              6.95850
# 9      382             Kajol           6        450              6.38043
#
#    googleHits  normalizedGoogleRank  normalizedRating
# 0     2460000               7.34283          10.00000
# 1     2670000               7.88458           9.22674
# ...

# %%
import seaborn as sns
g=sns.barplot(data=afternormalized,x="actorName",y="movieCount")
g.set_xticklabels(labels=afternormalized['actorName'],rotation=45)
# Out:
# [Text(0, 0, 'Aamir Khan'),
#  Text(1, 0, 'Shah Rukh Khan'),
#  Text(2, 0, 'Salman Khan'),
#  Text(3, 0, 'Katrina Kaif'),
#  Text(4, 0, 'Deepika Padukone'),
#  Text(5, 0, 'Hrithik Roshan'),
#  Text(6, 0, 'Priyanka Chopra'),
#  Text(7, 0, 'Kareena Kapoor'),
#  Text(8, 0, 'Ranbir Kapoor'),
#  Text(9, 0, 'Kajol')]

# %%
g=sns.barplot(data=afternormalized,x="actorName",y="normalizedRating")
g.set_xticklabels(labels=afternormalized['actorName'],rotation=45)
# Out:
# [Text(0, 0, 'Aamir Khan'),
#  Text(1, 0, 'Shah Rukh Khan'),
#  Text(2, 0, 'Salman Khan'),
#  Text(3, 0, 'Katrina Kaif'),
#  Text(4, 0, 'Deepika Padukone'),
#  Text(5, 0, 'Hrithik Roshan'),
#  Text(6, 0, 'Priyanka Chopra'),
#  Text(7, 0, 'Kareena Kapoor'),
#  Text(8, 0, 'Ranbir Kapoor'),
#  Text(9, 0, 'Kajol')]

# %%
Acc_to_movie=Actor.nlargest(10,"movieCount")
Acc_to_movie
# Out:
#     actorId          actorName  movieCount  ratingSum  normalizedMovieRank  \
# 18      391       Akshay Kumar          54       2950              4.38768
# 14      387         Ajay Devgn          49       2320              3.67524
# 11      384   Amitabh Bachchan          48       2140              3.40489
# 36      409        Sanjay Dutt          43       1740              3.00202
# 83      456       Sunil Shetty          42       1530              2.60714
# 7       380     Kareena Kapoor          37       2200              4.86016
# 2       375        Salman Khan          36       2340              5.40217
# 6       379    Priyanka Chopra          36       1990              4.45109
# 77      450        Anupam Kher          36       1310              2.60326
# 31      404  Abhishek Bachchan          34       1770              4.13619
#
#     googleHits  normalizedGoogleRank  normalizedRating
# 18     1960000               6.05294           6.38048
# ...

# %%
g=sns.barplot(data=Acc_to_movie,x="actorName",y="movieCount",palette="hls")
g.set_xticklabels(labels=Acc_to_movie['actorName'],rotation=45)
# Out:
# [Text(0, 0, 'Akshay Kumar'),
#  Text(1, 0, 'Ajay Devgn'),
#  Text(2, 0, 'Amitabh Bachchan'),
#  Text(3, 0, 'Sanjay Dutt'),
#  Text(4, 0, 'Sunil Shetty'),
#  Text(5, 0, 'Kareena Kapoor'),
#  Text(6, 0, 'Salman Khan'),
#  Text(7, 0, 'Priyanka Chopra'),
#  Text(8, 0, 'Anupam Kher'),
#  Text(9, 0, 'Abhishek Bachchan')]

# %%
googlehit=Actor.nlargest(10,"googleHits")
googlehit
# Out:
#     actorId         actorName  movieCount  ratingSum  normalizedMovieRank  \
# 2       375       Salman Khan          36       2340              5.40217
# 6       379   Priyanka Chopra          36       1990              4.45109
# 4       377  Deepika Padukone          16       1080              5.64674
# 7       380    Kareena Kapoor          37       2200              4.86016
# 11      384  Amitabh Bachchan          48       2140              3.40489
# 1       374    Shah Rukh Khan          23       2000              7.55009
# 5       378    Hrithik Roshan          16       1120              5.89130
# 10      383      John Abraham          27       1370              4.00725
# 14      387        Ajay Devgn          49       2320              3.67524
# 0       373        Aamir Khan          11       1170              9.44862
#
#     googleHits  normalizedGoogleRank  normalizedRating
# 2      3490000              10.00000           9.20821
# ...

# %%
g=sns.barplot(data=googlehit,x="actorName",y="googleHits",color="lightblue")
g.set_xticklabels(labels=googlehit['actorName'],rotation=45)
# Out:
# [Text(0, 0, 'Salman Khan'),
#  Text(1, 0, 'Priyanka Chopra'),
#  Text(2, 0, 'Deepika Padukone'),
#  Text(3, 0, 'Kareena Kapoor'),
#  Text(4, 0, 'Amitabh Bachchan'),
#  Text(5, 0, 'Shah Rukh Khan'),
#  Text(6, 0, 'Hrithik Roshan'),
#  Text(7, 0, 'John Abraham'),
#  Text(8, 0, 'Ajay Devgn'),
#  Text(9, 0, 'Aamir Khan')]

# %%
normalizedMovieRank=Actor.nlargest(10,"normalizedMovieRank")
normalizedMovieRank
# Out:
#     actorId       actorName  movieCount  ratingSum  normalizedMovieRank  \
# 15      388            Asin           5        560             10.00000
# 0       373      Aamir Khan          11       1170              9.44862
# 3       376    Katrina Kaif          17       1640              8.48082
# 12      385  Sonakshi Sinha           8        730              7.97011
# 1       374  Shah Rukh Khan          23       2000              7.55009
# 13      386      Alia Bhatt           4        340              7.35870
# 8       381   Ranbir Kapoor          11        890              6.95850
# 9       382           Kajol           6        450              6.38043
# 19      392  Anushka Sharma           7        500              6.03106
# 5       378  Hrithik Roshan          16       1120              5.89130
#
#     googleHits  normalizedGoogleRank  normalizedRating
# 15       35900               1.08918           6.75012
# 0      2460000               7.34283          10.00000
# ...

# %%
g=sns.barplot(data=normalizedMovieRank,x="actorName",y="normalizedMovieRank",color="lightblue")
g.set_xticklabels(labels=normalizedMovieRank['actorName'],rotation=45)
# Out:
# [Text(0, 0, 'Asin'),
#  Text(1, 0, 'Aamir Khan'),
#  Text(2, 0, 'Katrina Kaif'),
#  Text(3, 0, 'Sonakshi Sinha'),
#  Text(4, 0, 'Shah Rukh Khan'),
#  Text(5, 0, 'Alia Bhatt'),
#  Text(6, 0, 'Ranbir Kapoor'),
#  Text(7, 0, 'Kajol'),
#  Text(8, 0, 'Anushka Sharma'),
#  Text(9, 0, 'Hrithik Roshan')]

# %%
normalizedGoogleRank=Actor.nlargest(10,"normalizedGoogleRank")
normalizedGoogleRank
#but we don't need to do this because the actor who got the highest googlehits will 
#have the highest google Rank
# Out:
#     actorId         actorName  movieCount  ratingSum  normalizedMovieRank  \
# 2       375       Salman Khan          36       2340              5.40217
# 6       379   Priyanka Chopra          36       1990              4.45109
# 4       377  Deepika Padukone          16       1080              5.64674
# 7       380    Kareena Kapoor          37       2200              4.86016
# 11      384  Amitabh Bachchan          48       2140              3.40489
# 1       374    Shah Rukh Khan          23       2000              7.55009
# 5       378    Hrithik Roshan          16       1120              5.89130
# 10      383      John Abraham          27       1370              4.00725
# 14      387        Ajay Devgn          49       2320              3.67524
# 0       373        Aamir Khan          11       1170              9.44862
#
#     googleHits  normalizedGoogleRank  normalizedRating
# 2      3490000              10.00000           9.20821
# ...

# %% [markdown]
# # Director Dataset

# %%
Director.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 118 entries, 0 to 117
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   directorId            118 non-null    int64
#  1   directorName          117 non-null    object
#  2   movieCount            118 non-null    int64
#  3   ratingSum             118 non-null    int64
#  4   normalizedMovieRank   118 non-null    float64
#  5   googleHits            118 non-null    int64
#  6   normalizedGoogleRank  118 non-null    float64
#  7   normalizedRating      118 non-null    float64
# dtypes: float64(3), int64(4), object(1)
# memory usage: 7.5+ KB

# %%
Director.head()
# Out:
#    directorId     directorName  movieCount  ratingSum  normalizedMovieRank  \
# 0           1  Rajkumar Hirani           3        440             10.00000
# 1           2       Farah Khan           4        440              7.39474
# 2           3      Karan Johar           5        430              5.68947
# 3           4       Sajid Khan           4        350              5.79605
# 4           5     Rohit Shetty          10        950              6.32895
#
#    googleHits  normalizedGoogleRank  normalizedRating
# 0      146000               2.07796          10.00000
# 1     1060000               8.88317           8.78473
# 2     1050000               8.80872           7.10460
# 3      905000               7.72912           6.99780
# 4      437000               4.24461           6.83761

# %%
Director.shape
# Out:
# (118, 8)

# %%
Director.isna().sum()
# Out:
# directorId              0
# directorName            1
# movieCount              0
# ratingSum               0
# normalizedMovieRank     0
# googleHits              0
# normalizedGoogleRank    0
# normalizedRating        0
# dtype: int64

# %%
Director.dropna(inplace=True)

# %%
Director.isna().sum()
# Out:
# directorId              0
# directorName            0
# movieCount              0
# ratingSum               0
# normalizedMovieRank     0
# googleHits              0
# normalizedGoogleRank    0
# normalizedRating        0
# dtype: int64

# %%
Director.shape
# Out:
# (117, 8)

# %%
Movie=Director.nlargest(10,"movieCount")
Movie
# Out:
#     directorId               directorName  movieCount  ratingSum  \
# 28          29               Priyadarshan          19       1050
# 31          32            Ram Gopal Varma          17        680
# 46          47               Vikram Bhatt          16        640
# 17          18               David Dhawan          11        670
# 4            5               Rohit Shetty          10        950
# 33          34   Abbas Alibhai Burmawalla          10        580
# 34          35  Mastan Alibhai Burmawalla          10        580
# 39          40          Madhur Bhandarkar          10        490
# 54          55             Satish Kaushik           9        380
# 86          87           Mahesh Manjrekar           9        230
#
#     normalizedMovieRank  googleHits  normalizedGoogleRank  normalizedRating
# 28              3.50554      277000               3.05333           3.84718
# 31              2.42105      934000               7.94504           3.74350
# ...

# %%
import matplotlib.pyplot as plt
fig1,ax1=plt.subplots()
ax1.pie(Movie["movieCount"],labels=Movie["directorName"], autopct='%.0f%%')
ax1.set_title("Highest movie count according to Directors ")
plt.show()

# %%
g=sns.barplot(data=Movie,x="directorName",y="movieCount",color="lightpink")
g.set_xticklabels(labels=Movie['directorName'],rotation=45)
# Out:
# [Text(0, 0, 'Priyadarshan'),
#  Text(1, 0, 'Ram Gopal Varma'),
#  Text(2, 0, 'Vikram Bhatt'),
#  Text(3, 0, 'David Dhawan'),
#  Text(4, 0, 'Rohit Shetty'),
#  Text(5, 0, 'Abbas Alibhai Burmawalla'),
#  Text(6, 0, 'Mastan Alibhai Burmawalla'),
#  Text(7, 0, 'Madhur Bhandarkar'),
#  Text(8, 0, 'Satish Kaushik'),
#  Text(9, 0, 'Mahesh Manjrekar')]

# %%
normalizedRating_to_D=Director.nlargest(10,"normalizedRating")
normalizedRating_to_D
# Out:
#    directorId     directorName  movieCount  ratingSum  normalizedMovieRank  \
# 0           1  Rajkumar Hirani           3        440             10.00000
# 1           2       Farah Khan           4        440              7.39474
# 2           3      Karan Johar           5        430              5.68947
# 3           4       Sajid Khan           4        350              5.79605
# 4           5     Rohit Shetty          10        950              6.32895
# 5           6       Kabir Khan           3        270              5.97368
# 6           7      Anil Sharma           6        390              4.19737
# 7           8    Farhan Akhtar           4        290              4.73026
# 8           9  Siddharth Anand           5        400              5.26316
# 9          10     Anees Bazmee           7        600              5.66917
#
#    googleHits  normalizedGoogleRank  normalizedRating
# 0      146000               2.07796          10.00000
# ...

# %%
fig1,ax1=plt.subplots()
ax1.pie(normalizedRating_to_D["normalizedRating"],labels=normalizedRating_to_D["directorName"], autopct='%.0f%%',shadow=True,startangle=90)
ax1.set_title("Highest normalized rating according to Directors ")
plt.show()

# %%
googleHits_to_D=Director.nlargest(10,"googleHits")
googleHits_to_D
# Out:
#     directorId     directorName  movieCount  ratingSum  normalizedMovieRank  \
# 20          21  Raj Kumar Gupta           3        140              2.89474
# 6            7      Anil Sharma           6        390              4.19737
# 1            2       Farah Khan           4        440              7.39474
# 58          59        Dev Anand           4         80              1.00000
# 2            3      Karan Johar           5        430              5.68947
# 15          16       Imtiaz Ali           5        270              3.41579
# 27          28       N. Chandra           3        120              2.42105
# 37          38     Sanjay Gupta           5        180              2.13684
# 31          32  Ram Gopal Varma          17        680              2.42105
# 44          45   Anurag Kashyap           8        240              1.71053
#
#     googleHits  normalizedGoogleRank  normalizedRating
# 20     1210000              10.00000           4.60759
# ...

# %%
g=sns.barplot(data=googleHits_to_D,x="directorName",y="googleHits")
g.set_xticklabels(labels=googleHits_to_D['directorName'],rotation=45)
# Out:
# [Text(0, 0, 'Raj Kumar Gupta'),
#  Text(1, 0, 'Anil Sharma'),
#  Text(2, 0, 'Farah Khan'),
#  Text(3, 0, 'Dev Anand'),
#  Text(4, 0, 'Karan Johar'),
#  Text(5, 0, 'Imtiaz Ali'),
#  Text(6, 0, 'N. Chandra'),
#  Text(7, 0, 'Sanjay Gupta'),
#  Text(8, 0, 'Ram Gopal Varma'),
#  Text(9, 0, 'Anurag Kashyap')]

# %% [markdown]
# # Movie Dataset

# %%
Movie_.head()
# Out:
#       imdbId                              title  releaseYear  releaseDate  \
# 0  tt0118578                             Albela         2001  20 Apr 2001
# 1  tt0169102  Lagaan: Once Upon a Time in India         2001  08 May 2002
# 2  tt0187279           Meri Biwi Ka Jawab Nahin         2004  02 Jul 2004
# 3  tt0222024             Hum Tumhare Hain Sanam         2002  24 May 2002
# 4  tt0227194                         One 2 Ka 4         2001  30 Mar 2001
#
#                          genre  \
# 0                      Romance
# 1  Adventure | Drama | Musical
# 2              Action | Comedy
# 3              Drama | Romance
# 4      Action | Comedy | Drama
#
#                                              writers  \
# 0  Honey Irani (screenplay) | Honey Irani (story)...
# 1  Ashutosh Gowariker (story) | Ashutosh Gowarike...
# 2                                                NaN
# 3  K.S. Adiyaman | Arun Kumar (assistant dialogue...
# 4  Sanjay Chhel | Raaj Kumar Dahima (screenplay) ...
#
# ...

# %%
Movie_.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1284 entries, 0 to 1283
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   imdbId       1284 non-null   object
#  1   title        1284 non-null   object
#  2   releaseYear  1284 non-null   int64
#  3   releaseDate  1231 non-null   object
#  4   genre        1282 non-null   object
#  5   writers      1165 non-null   object
#  6   actors       1281 non-null   object
#  7   directors    1280 non-null   object
#  8   sequel       1281 non-null   float64
#  9   hitFlop      1284 non-null   int64
# dtypes: float64(1), int64(2), object(7)
# memory usage: 100.4+ KB

# %%
Movie_.shape
# Out:
# (1284, 10)

# %%
Movie_.isna().sum()
# Out:
# imdbId           0
# title            0
# releaseYear      0
# releaseDate     53
# genre            2
# writers        119
# actors           3
# directors        4
# sequel           3
# hitFlop          0
# dtype: int64

# %%
Movie_.dropna(inplace=True)

# %%
Movie_.isna().sum()
# Out:
# imdbId         0
# title          0
# releaseYear    0
# releaseDate    0
# genre          0
# writers        0
# actors         0
# directors      0
# sequel         0
# hitFlop        0
# dtype: int64

# %%
Movie_['First_Actor']=Movie_['actors'].str.split('|').str[0]
Movie_['Second_Actor']=Movie_['actors'].str.split('|').str[1]
Movie_['Third_Actor']=Movie_['actors'].str.split('|').str[2]
Movie_['Fourth_Actor']=Movie_['actors'].str.split('|').str[3]

# Add a new column month extracting the month  'releaseDate' column
Movie_['release_month'] = Movie_['releaseDate'].apply(lambda x: x.lstrip().split(' ')[1])


Movie_
# Out:
#          imdbId                              title  releaseYear  releaseDate  \
# 0     tt0118578                             Albela         2001  20 Apr 2001
# 1     tt0169102  Lagaan: Once Upon a Time in India         2001  08 May 2002
# 3     tt0222024             Hum Tumhare Hain Sanam         2002  24 May 2002
# 4     tt0227194                         One 2 Ka 4         2001  30 Mar 2001
# 5     tt0238936                             Devdas         2002  12 Jul 2002
# ...         ...                                ...          ...          ...
# 1275  tt3893476                              Spark         2014  10 Oct 2014
# 1276  tt4010306                          Jigariyaa         2014  10 Oct 2014
# 1277  tt4045666                Mumbai Delhi Mumbai         2014  05 Dec 2014
# 1278  tt4119196                  Love U Crazy Girl         2014  09 May 2014
# 1283  tt4228746                                Zid         2014  28 Nov 2014
#
#                             genre  \
# ...

# %%
Movie_.shape
# Out:
# (1131, 15)

# %%
g=sns.countplot(data=Movie_,x='genre',order=Movie_['genre'].value_counts().index[0:20])
#g.set_xticklabels(labels=Movie_['genre'],rotation=90)
plt.xticks(rotation = 90, fontsize = 12)
plt.xlabel('Genre', fontsize = 15,fontweight = 'bold')
plt.ylabel('Count of Total Movies', fontsize = 15,fontweight = 'bold')
plt.title('Top 20 Movie Genre', fontsize = 15,fontweight = 'bold')
# Out:
# Text(0.5, 1.0, 'Top 20 Movie Genre')

# %%
g=sns.countplot(data=Movie_,x='releaseYear',palette = 'Paired')
#g.set_xticklabels(labels=Movie_['genre'],rotation=90)
plt.xticks(rotation = 90, fontsize = 12)
plt.xlabel('Release Year', fontsize = 15,fontweight = 'bold')
plt.ylabel('Count of Total Movies', fontsize = 15,fontweight = 'bold')
plt.title('Total of Movies Release Each Year', fontsize = 15,fontweight = 'bold')
# Out:
# Text(0.5, 1.0, 'Total of Movies Release Each Year')

# %%
g=sns.countplot(data=Movie_,y='First_Actor',order=Movie_['First_Actor'].value_counts().index[0:20],palette = 'inferno')
plt.xticks(rotation = 90, fontsize = 12)
plt.xlabel('Total Movies', fontsize = 15,fontweight = 'bold')
plt.ylabel('First Actor', fontsize = 15,fontweight = 'bold')
plt.title('Total number of Movies by First Actor', fontsize = 15,fontweight = 'bold')
# Out:
# Text(0.5, 1.0, 'Total number of Movies by First Actor')

# %%
g=sns.countplot(data=Movie_,y='Second_Actor',order=Movie_['Second_Actor'].value_counts().index[0:20],palette = 'inferno')
plt.xticks(rotation = 90, fontsize = 12)
plt.xlabel('Total Movies', fontsize = 15,fontweight = 'bold')
plt.ylabel('Second Actor', fontsize = 15,fontweight = 'bold')
plt.title('Total number of Movies by Second Actor', fontsize = 15,fontweight = 'bold')
# Out:
# Text(0.5, 1.0, 'Total number of Movies by Second Actor')

# %%
g=sns.countplot(data=Movie_,y='Third_Actor',order=Movie_['Third_Actor'].value_counts().index[0:20],palette = 'inferno')
plt.xticks(rotation = 90, fontsize = 12)
plt.xlabel('Total Movies', fontsize = 15,fontweight = 'bold')
plt.ylabel('Third Actor', fontsize = 15,fontweight = 'bold')
plt.title('Total number of Movies by Third Actor', fontsize = 15,fontweight = 'bold')
# Out:
# Text(0.5, 1.0, 'Total number of Movies by Third Actor')

# %%
g=sns.countplot(data=Movie_,y='Fourth_Actor',order=Movie_['Fourth_Actor'].value_counts().index[0:20],palette = 'inferno')
plt.xticks(rotation = 90, fontsize = 12)
plt.xlabel('Total Movies', fontsize = 15,fontweight = 'bold')
plt.ylabel('Fourth Actor', fontsize = 15,fontweight = 'bold')
plt.title('Total number of Movies by Fourth Actor', fontsize = 15,fontweight = 'bold')
# Out:
# Text(0.5, 1.0, 'Total number of Movies by Fourth Actor')
